# %%
import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from video_to_frame import *

# %%
file_path = './hand/filter/laplacian_1.jpg'
image = cv2.imread(file_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

sns.distplot(gray, kde=True, hist=True)
plt.title("Pixel Value Distribution")
plt.xlabel("Pixel")
plt.ylabel("Count")
plt.xlim(1, 256)
plt.ylim(0, 0.20)
plt.show()
# Out:
# /tmp/ipykernel_167532/3034862072.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(gray, kde=True, hist=True)

# %%
file_path = './hand/filter/laplacian_2.jpg'
image = cv2.imread(file_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

sns.distplot(gray, kde=True, hist=True)
plt.title("Pixel Value Distribution")
plt.xlabel("Pixel")
plt.ylabel("Count")
plt.xlim(1, 256)
plt.ylim(0, 0.20)
plt.show()
# Out:
# /tmp/ipykernel_167532/3278300173.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(gray, kde=True, hist=True)
